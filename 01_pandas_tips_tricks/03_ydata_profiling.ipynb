# %% [markdown]
# Automatic EDA using ydata_profiling

# %%
import pandas as pd
import seaborn as sns
import ydata_profiling as yd

# %%
df = sns.load_dataset('titanic')

# %%
profile = yd.ProfileReport(df)
profile.to_file('./outputs/03_ydata_titanic.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_pop = pd.read_csv("./data/data.csv")

# %%
profile = yd.ProfileReport(df_pop)
profile.to_file('./outputs/03b_ydata_pak_population.html')
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\OWNER\Desktop\python_for_data_science\pandas_tips_tricks\03_ydata_profiling.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/OWNER/Desktop/python_for_data_science/pandas_tips_tricks/03_ydata_profiling.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> profile = yd.ProfileReport(df_pop)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OWNER/Desktop/python_for_data_science/pandas_tips_tricks/03_ydata_profiling.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> profile.to_file('./outputs/03b_ydata_pak_population.html')
#
# File c:\Users\OWNER\anaconda3\envs\ydata_profiling\lib\site-packages\ydata_profiling\profile_report.py:355, in ProfileReport.to_file(self, output_file, silent)
#     352         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
# ...

# %%
pip install skimpy
# Out:
# ...
#      ---------------------------------------- 0.0/143.0 kB ? eta -:--:--
#      ------------------------- ------------- 92.2/143.0 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 143.0/143.0 kB 2.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      -------------------------------------- 118.7/118.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 2.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/24.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.7 MB 991.0 kB/s eta 0:00:25
#    ---------------------------------------- 0.1/24.7 MB 1.4 MB/s eta 0:00:18
#    ---------------------------------------- 0.3/24.7 MB 1.8 MB/s eta 0:00:14
#     --------------------------------------- 0.3/24.7 MB 1.8 MB/s eta 0:00:14
# ...

# %%
import pandas as pd
import seaborn as sns   
from skimpy import skim
