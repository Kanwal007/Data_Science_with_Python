# %% [markdown]
# Apple_EDA

# %% [markdown]
# ## 1. Importing Libraries

# %%
# 1 Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy as sp

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(3)
# Out:
#                 App_Id        App_Name  \
# 0  com.hkbu.arc.apaper  A+ Paper Guide
# 1  com.dmitriev.abooks         A-Books
# 2       no.terp.abooks         A-books
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# 1             4+  13135872.0                 10.0  2015-08-31T19:31:32Z
# 2             4+  21943296.0                  9.0  2021-04-14T07:00:00Z
#
#                 Updated Version  Price Currency  Free  DeveloperId  \
# 0  2018-12-21T21:30:36Z   1.1.2    0.0      USD  True   1375410542
# 1  2019-07-23T20:31:09Z     1.3    0.0      USD  True   1031572001
# ...

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %%
print(f"Number of rows:{df.shape[0]} and {df.shape[1]} columns")
# Out:
# Number of rows:1230376 and 21 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %%
# Observation : There are 7 numeric columns in original dataset
# Column Size_byte is in bytes we will convert it to MB

# %%
# Missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Website          643988
# Developer_Url                1109
# Price                         490
# Size_Bytes                    224
# Released                        3
# App_Name                        1
# Free                            0
# Current_Version_Score           0
# Reviews                         0
# Average_User_Rating             0
# Developer                       0
# DeveloperId                     0
# App_Id                          0
# Currency                        0
# Version                         0
# Updated                         0
# Required_IOS_Version            0
# Content_Rating                  0
# Primary_Genre                   0
# AppStore_Url                    0
# Current_Version_Reviews         0
# dtype: int64

# %%
# Exploratory data analysis and visualization
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Missing values')
# Out:
# Text(0.5, 1.0, 'Missing values')

# %%
missing_percentage = (df.isnull().sum().sort_values(ascending=False) / len(df)) * 100
missing_percentage
# Out:
# Developer_Website          52.340748
# Developer_Url               0.090135
# Price                       0.039825
# Size_Bytes                  0.018206
# Released                    0.000244
# App_Name                    0.000081
# Free                        0.000000
# Current_Version_Score       0.000000
# Reviews                     0.000000
# Average_User_Rating         0.000000
# Developer                   0.000000
# DeveloperId                 0.000000
# App_Id                      0.000000
# Currency                    0.000000
# Version                     0.000000
# Updated                     0.000000
# Required_IOS_Version        0.000000
# Content_Rating              0.000000
# Primary_Genre               0.000000
# AppStore_Url                0.000000
# Current_Version_Reviews     0.000000
# dtype: float64

# %%
# Dealing with missing values
df.drop('Developer_Website', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %%
# dealing with missing values
df['Price'] = df.Price.fillna(value=df['Price'].mean())
df['Size_Bytes'] = df.Size_Bytes.fillna(value=df['Size_Bytes'].mean())

df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Url              1109
# Released                      3
# App_Name                      1
# App_Id                        0
# Currency                      0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# Free                          0
# Price                         0
# Version                       0
# Updated                       0
# Required_IOS_Version          0
# Size_Bytes                    0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %%
# To view specific rows with missing values
df[df['Released'].isnull()].head(5)
# Out:
#                                                App_Id  \
# 264853  com.ironhidegames.frontiers.universal.premium
# 836858                    com.redgamesco.transformers
# 919513    com.crayolallc.crayola-create-and-play-plus
#
#                             App_Name  \
# 264853    Kingdom Rush Frontiers TD+
# 836858  Transformers: Tactical Arena
# 919513      Crayola Create and Play+
#
#                                              AppStore_Url Primary_Genre  \
# 264853  https://apps.apple.com/us/app/kingdom-rush-fro...         Games
# 836858  https://apps.apple.com/us/app/transformers-tac...         Games
# 919513  https://apps.apple.com/us/app/crayola-create-a...         Games
#
#        Content_Rating    Size_Bytes Required_IOS_Version Released  \
# 264853            12+  7.510857e+07                 13.0      NaN
# 836858             9+  7.510857e+07               13.5.0      NaN
# 919513             4+  7.510857e+07                   13      NaN
#
# ...

# %%
df[df['Developer_Url'].isnull()].head(5)
# Out:
#                            App_Id         App_Name  \
# 2382              com.TroopAdmin2  C&S Troop Admin
# 2827       com.dhrubajyoti.bangla    Bangla Rhymes
# 3498  com.f1rstmotors.f1rstmotors     F1RST MOTORS
# 5820       tr.com.okuvaryum.mobil        Okuvaryum
# 5821        tr.com.okuvaryum.okul   Okuvaryum Okul
#
#                                            AppStore_Url Primary_Genre  \
# 2382  https://apps.apple.com/us/app/c-s-troop-admin/...      Business
# 2827  https://apps.apple.com/us/app/bangla-rhymes/id...     Education
# 3498  https://apps.apple.com/us/app/f1rst-motors/id1...      Business
# 5820  https://apps.apple.com/us/app/okuvaryum/id1493...     Education
# 5821  https://apps.apple.com/us/app/okuvaryum-okul/i...     Education
#
#      Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 2382             4+  87355392.0                 10.0  2021-06-04T07:00:00Z
# 2827             4+  56445952.0                  9.1  2019-03-23T18:27:49Z
# ...

# %%
df[df['App_Name'].isnull()].head(5)
# Out:
#                 App_Id App_Name  \
# 964888  se.promedia.NA      NaN
#
#                                              AppStore_Url Primary_Genre  \
# 964888  https://apps.apple.com/us/app/na/id449134868?uo=4          News
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 964888             4+  19528704.0                  9.0  2011-08-08T11:45:30Z
#
#                      Updated Version  Price Currency  Free  DeveloperId  \
# 964888  2020-12-21T14:08:02Z   8.1.2    0.0      USD  True    449134871
#
#        Developer                                      Developer_Url  \
# 964888  Promedia  https://apps.apple.com/us/developer/promedia/i...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 964888                  5.0        1                    5.0
#
#         Current_Version_Reviews
# 964888                        1

# %%
df.dropna(subset=['Released'],inplace=True)
df.dropna(subset=['App_Name'],inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Url              1109
# App_Id                        0
# App_Name                      0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# Free                          0
# Currency                      0
# Price                         0
# Version                       0
# Updated                       0
# Released                      0
# Required_IOS_Version          0
# Size_Bytes                    0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
boolean = df['App_Name'].duplicated().any()
boolean
# Out:
# True

# %%
df['App_Name'].value_counts().sort_values(ascending=False)
# Out:
# App_Name
# Vanguard              6
# Linker                5
# Bloom                 5
# Lume                  4
# Vibe                  4
#                      ..
# Twin Creeks           1
# Twine Garage          1
# Twippy                1
# TwitMore              1
# Sổ Điểm Thông Minh    1
# Name: count, Length: 1223507, dtype: int64

# %%
df[df['App_Name'] == 'Linker']
# Out:
#                         App_Id App_Name  \
# 139096   com.cheerg.LinkerTest   Linker
# 462132           br.com.linker   Linker
# 745039      team.linker.linker   Linker
# 954862         com.kubo.Linker   Linker
# 1206501  com.tilon.elcloud.rdc   Linker
#
#                                               AppStore_Url     Primary_Genre  \
# 139096   https://apps.apple.com/us/app/linker/id1208886...         Lifestyle
# 462132   https://apps.apple.com/us/app/linker/id1472621...           Finance
# 745039   https://apps.apple.com/us/app/linker/id1558364...  Health & Fitness
# 954862   https://apps.apple.com/us/app/linker/id1169163...            Travel
# 1206501  https://apps.apple.com/us/app/linker/id1215552...         Utilities
#
#         Content_Rating   Size_Bytes Required_IOS_Version  \
# 139096              4+   21876736.0                 10.0
# 462132              4+  169309184.0                 12.0
# 745039              4+   97497088.0                 10.0
# ...

# %%
# Although app names are duplicate, the records are unique as a whole, with varying version, Appids and release date
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1230372 entries, 0 to 1230375
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230372 non-null  object
#  1   App_Name                 1230372 non-null  object
#  2   AppStore_Url             1230372 non-null  object
#  3   Primary_Genre            1230372 non-null  object
#  4   Content_Rating           1230372 non-null  object
#  5   Size_Bytes               1230372 non-null  float64
#  6   Required_IOS_Version     1230372 non-null  object
#  7   Released                 1230372 non-null  object
#  8   Updated                  1230372 non-null  object
#  9   Version                  1230372 non-null  object
#  10  Price                    1230372 non-null  float64
#  11  Currency                 1230372 non-null  object
#  12  Free                     1230372 non-null  bool
# ...

# %%
df['Size_Bytes'].unique()
# Out:
# array([2.19934720e+07, 1.31358720e+07, 2.19432960e+07, ...,
#        1.19404544e+08, 5.96570000e+05, 5.06896000e+05])

# %%
df['Price'].unique()
# Out:
# array([0.00000000e+00, 2.99000000e+00, 1.99000000e+00, 9.90000000e-01,
#        4.99000000e+00, 9.99000000e+00, 5.99000000e+00, 6.99000000e+00,
#        1.69900000e+01, 1.99900000e+01, 3.99900000e+01, 5.99900000e+01,
#        8.99000000e+00, 7.99000000e+00, 1.89900000e+01, 3.99000000e+00,
#        2.49900000e+01, 1.49900000e+01, 2.89900000e+01, 2.19900000e+01,
#        1.39900000e+01, 1.09900000e+01, 1.19900000e+01, 1.29990000e+02,
#        2.29900000e+01, 1.39990000e+02, 2.59900000e+01, 1.29900000e+01,
#        4.99900000e+01, 2.39900000e+01, 1.19990000e+02, 7.99900000e+01,
#        1.79900000e+01, 4.99990000e+02, 2.49990000e+02, 1.99990000e+02,
#        2.29990000e+02, 3.49900000e+01, 2.09900000e+01, 9.99900000e+01,
#        3.39900000e+01, 5.49900000e+01, 4.59900000e+01, 4.49900000e+01,
#        2.99900000e+01, 6.99900000e+01, 2.79900000e+01, 8.49900000e+01,
#        6.49900000e+01, 1.59900000e+01, 2.69900000e+01, 3.59900000e+01,
# ...

# %%
df['Average_User_Rating'].unique()
# Out:
# array([0.     , 5.     , 4.78132, ..., 4.00352, 3.91608, 4.82733])

# %%
df['Reviews'].unique()
# Out:
# array([    0,     1,  1285, ..., 12691, 35476, 10481], dtype=int64)

# %%
df['Current_Version_Score'].unique()
# Out:
# array([0.     , 5.     , 4.78132, ..., 4.00352, 3.91608, 4.82733])

# %%
df['Currency'].unique()
# Out:
# array(['USD'], dtype=object)

# %%
df['Content_Rating'].unique()
# Out:
# array(['4+', '17+', '9+', '12+', 'Not yet rated'], dtype=object)

# %%
# Conversion of Size_Bytes to MB
df['Size_MB'] = df['Size_Bytes'].apply(lambda x :(float(x) /1024)/1024)

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews', 'Size_MB'],
#       dtype='object')

# %%
df.Average_User_Rating.describe()
# Out:
# count    1.230372e+06
# mean     1.788388e+00
# std      2.154105e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      4.333330e+00
# max      5.000000e+00
# Name: Average_User_Rating, dtype: float64

# %%
df['Type'] = np.where(df['Free'] == True, 'Free', 'Paid')

# %%
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
for i in df.Content_Rating.unique():
    print(i)
# Out:
# 4+
# 17+
# 9+
# 12+
# Not yet rated

# %%
df["Content_Rating"] = df["Content_Rating"].replace("4+","Children")
df["Content_Rating"] = df["Content_Rating"].replace("17+","Adult")
df["Content_Rating"] = df["Content_Rating"].replace("9+","Children")
df["Content_Rating"] = df["Content_Rating"].replace("12+","Teens")
df["Content_Rating"] = df["Content_Rating"].replace("Not yet rated","Everyone")

# %%
agegroup = df['Content_Rating'].unique()
custom_order = ['Children','Teens','Everyone','Adult']

sorted_array = sorted(['Children','Teens','Everyone','Adult'], key=lambda x : custom_order.index(x))
print(sorted_array)
# Out:
# ['Children', 'Teens', 'Everyone', 'Adult']

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0       Children  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
df.Reviews.min()
# Out:
# 0

# %%
df.Reviews.max()
# Out:
# 22685334

# %%
df.Reviews.describe()
# Out:
# count    1.230372e+06
# mean     8.259505e+02
# std      5.016059e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      3.000000e+00
# max      2.268533e+07
# Name: Reviews, dtype: float64

# %%
df[df['Reviews'] == 22685334]
# Out:
#                         App_Id                        App_Name  \
# 415817  com.google.ios.youtube  YouTube: Watch, Listen, Stream
#
#                                              AppStore_Url  Primary_Genre  \
# 415817  https://apps.apple.com/us/app/youtube-watch-li...  Photo & Video
#
#        Content_Rating   Size_Bytes Required_IOS_Version              Released  \
# 415817          Adult  261849088.0                 12.0  2012-09-11T07:23:19Z
#
#                      Updated  Version  Price Currency  Free  DeveloperId  \
# 415817  2021-10-10T23:03:29Z  16.40.3    0.0      USD  True    281956209
#
#          Developer                                      Developer_Url  \
# 415817  Google LLC  https://apps.apple.com/us/developer/google-llc...
#
#         Average_User_Rating   Reviews  Current_Version_Score  \
# 415817              4.68757  22685334                4.68757
#
#         Current_Version_Reviews    Size_MB  Type
# 415817                 22685334  249.71875  Free

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews', 'Size_MB', 'Type'],
#       dtype='object')

# %%
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0       Children  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
df['Reviews'].unique()
# Out:
# array([    0,     1,  1285, ..., 12691, 35476, 10481], dtype=int64)

# %%
df['ReviewCategory'] = 'NoReviewsProvided'
df.loc[(df['Reviews'] > 0) & (df['Reviews'] < 1000), 'ReviewCategory'] = 'LessThan10k'
df.loc[(df['Reviews'] > 1000) & (df['Reviews'] < 500000), 'ReviewCategory'] = 'Between 10k and 500k'
df.loc[(df['Reviews'] > 500000) & (df['Reviews'] < 1000000), 'ReviewCategory'] = 'Between 500k and 1M'
df.loc[(df['Reviews'] > 1000000) & (df['Reviews'] < 22685334), 'ReviewCategory'] = 'Million Plus'

df['ReviewCategory'].value_counts()
# Out:
# ReviewCategory
# NoReviewsProvided       684332
# LessThan10k             521869
# Between 10k and 500k     23874
# Million Plus               151
# Between 500k and 1M        146
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1230372 entries, 0 to 1230375
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230372 non-null  object
#  1   App_Name                 1230372 non-null  object
#  2   AppStore_Url             1230372 non-null  object
#  3   Primary_Genre            1230372 non-null  object
#  4   Content_Rating           1230372 non-null  object
#  5   Size_Bytes               1230372 non-null  float64
#  6   Required_IOS_Version     1230372 non-null  object
#  7   Released                 1230372 non-null  object
#  8   Updated                  1230372 non-null  object
#  9   Version                  1230372 non-null  object
#  10  Price                    1230372 non-null  float64
#  11  Currency                 1230372 non-null  object
#  12  Free                     1230372 non-null  bool
# ...

# %%
df['Average_User_Rating'] = df["Average_User_Rating"].round().astype(int)

# %%
df.Average_User_Rating.unique()
# Out:
# array([0, 5, 3, 4, 2, 1])

# %%
# Questions
#1. what are the top 10 categories that are installed from the App Store 
#2. what are the highest top 10 rated primary-genre based on Average_User_Rating
#3. which primary genre has the highest count of paid and free apps
#4. what are the top 5 paid apps that have the highest ratings
#5. what are the top 5 free apps that have the highest ratings
#6. apps with highest content rating
#7. years in which max apps were released
#8. size in MBs vs price of apps
#9. years in which max apps were released
#10. what type of Genre attracted the most downloads
#11. what type of content rating attracted the most downloads
#12. what type of primary genre attracted the most downloads
#13. interdependency of numeric attributes on each other

# %%
top_categories = df['Primary_Genre'].value_counts().head(10)
print(top_categories)
# Out:
# Primary_Genre
# Games               193746
# Business            128297
# Education           119174
# Utilities            94007
# Lifestyle            84565
# Food & Drink         73157
# Health & Fitness     60724
# Productivity         59430
# Entertainment        53147
# Shopping             49537
# Name: count, dtype: int64

# %%
plt.bar(top_categories.index, top_categories.values)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Top 10 Categories in App Store')
plt.xticks(rotation=90)
plt.show()

# %%
top_rated_genres = df.groupby('Primary_Genre')['Average_User_Rating'].mean().sort_values(ascending=False).head(10)
print(top_rated_genres)
# Out:
# Primary_Genre
# Weather              2.622509
# Games                2.566412
# Photo & Video        2.316446
# Music                2.264232
# Book                 2.193515
# Reference            2.191082
# Finance              2.133470
# Entertainment        2.025759
# Social Networking    1.998860
# Health & Fitness     1.858968
# Name: Average_User_Rating, dtype: float64

# %%
plt.pie(top_rated_genres.values, labels=top_rated_genres.index, autopct='%1.1f%%')
plt.title('Top 10 Highest Rated Primary Genres')
plt.axis('equal')
plt.show()

# %%
plt.barh(top_rated_genres.index, top_rated_genres.values)
plt.xlabel('Average User Rating')
plt.ylabel('Primary Genre')
plt.title('Top 10 Highest Rated Primary Genres')
plt.show()

# %%
#3. which primary genre has the highest count of paid and free apps
paid_apps = df[df['Price'] > 0]
free_apps = df[df['Price'] == 0]

paid_genre_counts = paid_apps['Primary_Genre'].value_counts()
free_genre_counts = free_apps['Primary_Genre'].value_counts()

highest_paid_genre = paid_genre_counts.idxmax()
highest_free_genre = free_genre_counts.idxmax()

print(f"The primary genre with the highest count of paid apps is: {highest_paid_genre}")
print(f"The primary genre with the highest count of free apps is: {highest_free_genre}")
# Out:
# The primary genre with the highest count of paid apps is: Education
# The primary genre with the highest count of free apps is: Games

# %%
# group the dataset by Primary_Genre and Type, and count the number of apps in each group
genre_counts = df.groupby(['Primary_Genre', 'Type']).size().reset_index(name='Count')
# # separate the free apps
top10_free_apps = genre_counts[genre_counts['Type'] == 'Free']
# ##load top 10 free apps
top_10_free_genres = top10_free_apps.sort_values(by='Count', ascending=False).head(10)

# top_10_free_genres

# # separate the free apps
top10_paid_apps = genre_counts[genre_counts['Type'] == 'Paid']
# ##load top 10 free apps
top_10_paid_genres = top10_paid_apps.sort_values(by='Count', ascending=False).head(10)

# %%
top_10_free_genres.head(5)
# Out:
#    Primary_Genre  Type   Count
# 14         Games  Free  177409
# 2       Business  Free  125535
# 6      Education  Free  101799
# 48     Utilities  Free   84284
# 20     Lifestyle  Free   81295

# %%
# 4. what are the top 5 paid apps that have the highest ratings
top_5_paid_apps = df[df['Type'] == 'Paid'].nlargest(5, 'Average_User_Rating')
top_5_paid_apps
# Out:
#                                     App_Id                App_Name  \
# 12          com.laltrello.aabigbookandmore    AA Big Book and More
# 32   com.jhdigitalsolutions.lastenaakkoset     Aakkospeli Lapsille
# 87                 com.heinemann.prompting   F&P Prompting Guide 1
# 199  com.talespring.carlosbenson.awpeanuts  Gabe and the Pesky Bug
# 289                 com.eblong.hadeanlands            Hadean Lands
#
#                                           AppStore_Url Primary_Genre  \
# 12   https://apps.apple.com/us/app/aa-big-book-and-...     Lifestyle
# 32   https://apps.apple.com/us/app/aakkospeli-lapsi...         Games
# 87   https://apps.apple.com/us/app/f-p-prompting-gu...     Education
# 199  https://apps.apple.com/us/app/gabe-and-the-pes...          Book
# 289  https://apps.apple.com/us/app/hadean-lands/id9...         Games
#
#     Content_Rating   Size_Bytes Required_IOS_Version              Released  \
# ...

# %%
# 5. what are the top 5 free apps that have the highest ratings
top_5_free_apps = df[df['Type'] == 'Free'].nlargest(5, 'Average_User_Rating')
top_5_free_apps
# Out:
#                                   App_Id  \
# 1                    com.dmitriev.abooks
# 10  com.pitashi.audiojoy.aacompanionfree
# 11            com.goodbarber.bigbookfree
# 16       com.pitashi.readradio.aastories
# 19      com.pitashi.readradio.aaspeakers
#
#                                        App_Name  \
# 1                                       A-Books
# 10  AA Audio Companion for Alcoholics Anonymous
# 11                     AA Big Book (Unofficial)
# 16                 AA Big Book Sobriety Stories
# 19                  AA Speaker Tapes & 12 Steps
#
#                                          AppStore_Url     Primary_Genre  \
# 1   https://apps.apple.com/us/app/a-books/id103157...              Book
# 10  https://apps.apple.com/us/app/aa-audio-compani...              Book
# 11  https://apps.apple.com/us/app/aa-big-book-unof...              Book
# 16  https://apps.apple.com/us/app/aa-big-book-sobr...              Book
# ...

# %%
# 6. what are the top 5 paid apps that have the highest reviews
top_5_paid_apps = df[df['Type'] == 'Paid'].nlargest(5, 'Reviews')
top_5_paid_apps
# Out:
#                          App_Id                        App_Name  \
# 793847   com.mojang.minecraftpe                       Minecraft
# 1130013  com.WhatsPad.messenger  Messaging for WhatsApp on iPad
# 1172313    com.jackadam.darksky                Dark Sky Weather
# 360724   com.novosoft.TurboScan     TurboScan™ Pro: PDF scanner
# 217581       com.goodnotesapp.x                     GoodNotes 5
#
#                                               AppStore_Url      Primary_Genre  \
# 793847   https://apps.apple.com/us/app/minecraft/id4795...              Games
# 1130013  https://apps.apple.com/us/app/messaging-for-wh...  Social Networking
# 1172313  https://apps.apple.com/us/app/dark-sky-weather...            Weather
# 360724   https://apps.apple.com/us/app/turboscan-pro-pd...           Business
# 217581   https://apps.apple.com/us/app/goodnotes-5/id14...       Productivity
#
#         Content_Rating   Size_Bytes Required_IOS_Version  \
# ...

# %%
# 7. what are the top 5 free apps that have the highest reviews
top_5_free_apps = df[df['Type'] == 'Free'].nlargest(5, 'Reviews')
top_5_free_apps
# Out:
#                            App_Id                        App_Name  \
# 415817     com.google.ios.youtube  YouTube: Watch, Listen, Stream
# 996310        com.burbn.instagram                       Instagram
# 647929         com.spotify.client  Spotify New Music and Podcasts
# 483342     net.kortina.labs.Venmo                           Venmo
# 580482  doordash.DoorDashConsumer        DoorDash - Food Delivery
#
#                                              AppStore_Url  Primary_Genre  \
# 415817  https://apps.apple.com/us/app/youtube-watch-li...  Photo & Video
# 996310  https://apps.apple.com/us/app/instagram/id3898...  Photo & Video
# 647929  https://apps.apple.com/us/app/spotify-new-musi...          Music
# 483342  https://apps.apple.com/us/app/venmo/id35172742...        Finance
# 580482  https://apps.apple.com/us/app/doordash-food-de...   Food & Drink
#
#        Content_Rating   Size_Bytes Required_IOS_Version              Released  \
# ...

# %%
#8. what are the top 5 paid apps that have the highest current version score
top_5_paid_apps = df[df['Type'] == 'Paid'].nlargest(5, 'Current_Version_Score')
top_5_paid_apps
# Out:
#                                      App_Id                       App_Name  \
# 32    com.jhdigitalsolutions.lastenaakkoset            Aakkospeli Lapsille
# 87                  com.heinemann.prompting          F&P Prompting Guide 1
# 289                  com.eblong.hadeanlands                   Hadean Lands
# 405                   jp.co.unbalance.words  Garden of Words Film Art Book
# 459  com.iguruapps.jaapsahib.universal.paid            Jaap Sahib Ji Paath
#
#                                           AppStore_Url Primary_Genre  \
# 32   https://apps.apple.com/us/app/aakkospeli-lapsi...         Games
# 87   https://apps.apple.com/us/app/f-p-prompting-gu...     Education
# 289  https://apps.apple.com/us/app/hadean-lands/id9...         Games
# 405  https://apps.apple.com/us/app/garden-of-words-...          Book
# 459  https://apps.apple.com/us/app/jaap-sahib-ji-pa...          Book
#
#     Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# ...

# %%
#9. what are the top 5 free apps that have the highest current version score
top_5_free_apps = df[df['Type'] == 'Free'].nlargest(5, 'Current_Version_Score')
top_5_free_apps
# Out:
#                                     App_Id  \
# 1                      com.dmitriev.abooks
# 20        com.gentouchstudios.aaabcvuilite
# 21           com.alpigames.fairylandpuzzle
# 24  com.partnergomobilephoneapps.bandbcafe
# 28              com.hemsedalsite.AABMobile
#
#                                     App_Name  \
# 1                                    A-Books
# 20  Aaabc Vui Lite - Bang chu cai tieng viet
# 21             AAA³ Little Ponies & Unicorns
# 24                                  B&B Cafe
# 28                                AAB Mobile
#
#                                          AppStore_Url Primary_Genre  \
# 1   https://apps.apple.com/us/app/a-books/id103157...          Book
# 20  https://apps.apple.com/us/app/aaabc-vui-lite-b...          Book
# 21  https://apps.apple.com/us/app/aaa-little-ponie...         Games
# 24  https://apps.apple.com/us/app/b-b-cafe/id15643...          Book
# 28  https://apps.apple.com/us/app/aab-mobile/id147...     Education
#
# ...

# %%
# 10. what are the top 5 paid apps that have the highest current version reviews
top_5_paid_apps = df[df['Type'] == 'Paid'].nlargest(5, 'Current_Version_Reviews')
top_5_paid_apps
# Out:
#                          App_Id                        App_Name  \
# 793847   com.mojang.minecraftpe                       Minecraft
# 1130013  com.WhatsPad.messenger  Messaging for WhatsApp on iPad
# 1172313    com.jackadam.darksky                Dark Sky Weather
# 360724   com.novosoft.TurboScan     TurboScan™ Pro: PDF scanner
# 217581       com.goodnotesapp.x                     GoodNotes 5
#
#                                               AppStore_Url      Primary_Genre  \
# 793847   https://apps.apple.com/us/app/minecraft/id4795...              Games
# 1130013  https://apps.apple.com/us/app/messaging-for-wh...  Social Networking
# 1172313  https://apps.apple.com/us/app/dark-sky-weather...            Weather
# 360724   https://apps.apple.com/us/app/turboscan-pro-pd...           Business
# 217581   https://apps.apple.com/us/app/goodnotes-5/id14...       Productivity
#
#         Content_Rating   Size_Bytes Required_IOS_Version  \
# ...

# %%
#11. what are the top 5 free apps that have the highest current version reviews
top_5_free_apps = df[df['Type'] == 'Free'].nlargest(5, 'Current_Version_Reviews')
top_5_free_apps
# Out:
#                            App_Id                        App_Name  \
# 415817     com.google.ios.youtube  YouTube: Watch, Listen, Stream
# 996310        com.burbn.instagram                       Instagram
# 647929         com.spotify.client  Spotify New Music and Podcasts
# 483342     net.kortina.labs.Venmo                           Venmo
# 580482  doordash.DoorDashConsumer        DoorDash - Food Delivery
#
#                                              AppStore_Url  Primary_Genre  \
# 415817  https://apps.apple.com/us/app/youtube-watch-li...  Photo & Video
# 996310  https://apps.apple.com/us/app/instagram/id3898...  Photo & Video
# 647929  https://apps.apple.com/us/app/spotify-new-musi...          Music
# 483342  https://apps.apple.com/us/app/venmo/id35172742...        Finance
# 580482  https://apps.apple.com/us/app/doordash-food-de...   Food & Drink
#
#        Content_Rating   Size_Bytes Required_IOS_Version              Released  \
# ...

# %%
#12. what are the top 5 paid apps that have the highest average user rating
top_5_paid_apps = df[df['Type'] == 'Paid'].nlargest(5, 'Average_User_Rating')
top_5_paid_apps
# Out:
#                                     App_Id                App_Name  \
# 12          com.laltrello.aabigbookandmore    AA Big Book and More
# 32   com.jhdigitalsolutions.lastenaakkoset     Aakkospeli Lapsille
# 87                 com.heinemann.prompting   F&P Prompting Guide 1
# 199  com.talespring.carlosbenson.awpeanuts  Gabe and the Pesky Bug
# 289                 com.eblong.hadeanlands            Hadean Lands
#
#                                           AppStore_Url Primary_Genre  \
# 12   https://apps.apple.com/us/app/aa-big-book-and-...     Lifestyle
# 32   https://apps.apple.com/us/app/aakkospeli-lapsi...         Games
# 87   https://apps.apple.com/us/app/f-p-prompting-gu...     Education
# 199  https://apps.apple.com/us/app/gabe-and-the-pes...          Book
# 289  https://apps.apple.com/us/app/hadean-lands/id9...         Games
#
#     Content_Rating   Size_Bytes Required_IOS_Version              Released  \
# ...

# %%
#13. what are the top 5 free apps that have the highest average user rating
top_5_free_apps = df[df['Type'] == 'Free'].nlargest(5, 'Average_User_Rating')
top_5_free_apps
# Out:
#                                   App_Id  \
# 1                    com.dmitriev.abooks
# 10  com.pitashi.audiojoy.aacompanionfree
# 11            com.goodbarber.bigbookfree
# 16       com.pitashi.readradio.aastories
# 19      com.pitashi.readradio.aaspeakers
#
#                                        App_Name  \
# 1                                       A-Books
# 10  AA Audio Companion for Alcoholics Anonymous
# 11                     AA Big Book (Unofficial)
# 16                 AA Big Book Sobriety Stories
# 19                  AA Speaker Tapes & 12 Steps
#
#                                          AppStore_Url     Primary_Genre  \
# 1   https://apps.apple.com/us/app/a-books/id103157...              Book
# 10  https://apps.apple.com/us/app/aa-audio-compani...              Book
# 11  https://apps.apple.com/us/app/aa-big-book-unof...              Book
# 16  https://apps.apple.com/us/app/aa-big-book-sobr...              Book
# ...
